# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../../data/twitter-scraped-data/uchodzcy/processed.csv")

# %%
data.head()
# Out:
#                     id      conversation_id                 date  \
# 0  1498447814581538820  1498370105960550405  2022-03-01 00:59:33
# 1  1498447560859688967  1498400534742683648  2022-03-01 00:58:32
# 2  1498447441032626178  1498434110800510978  2022-03-01 00:58:04
# 3  1498446771881664516  1498278861129273351  2022-03-01 00:55:24
# 4  1498445748219875330  1498292629225750532  2022-03-01 00:51:20
#
#                                                tweet hashtags  \
# 0  @kowbojka926 @lkwarzecha Za parę lat ci uchodź...       []
# 1  @LucjanDrobosz @IjonTic46870505 @JaninaOchojsk...       []
# 2  @OnetWiadomosci Jadą islamscy"uchodźcy" lecz t...       []
# 3  @gomapdaa bo polakom od zawsze wpajane jest że...       []
# 4  @PatrykJanikowsk @AleBarszczewski Póki co ucho...       []
#
#            user_id_str         username                      name  \
# 0  1429441133483110400  NacjonalistaCWP                    Michał
# 1  1497657909907439618     Asia09491061                      Asia
# 2   952575246074351618         IwvwOrka                  Waivonne
# 3  1275873656065982467       ttaeminism                     snape
# 4  1083721532403269632          iktp_pl  I komu to przeszkadzało?
#
#                                                 link  \
# 0  https://twitter.com/NacjonalistaCWP/status/149...
# 1  https://twitter.com/Asia09491061/status/149844...
# 2  https://twitter.com/IwvwOrka/status/1498447441...
# 3  https://twitter.com/ttaeminism/status/14984467...
# 4  https://twitter.com/iktp_pl/status/14984457482...
#
#                               urls  ... lg_noun_to_verb_ratio  \
# 0                               []  ...                   3.0
# 1                               []  ...                   1.0
# 2  ['https://t.me/RVvoenkor/1964']  ...                  -1.0
# 3                               []  ...                   5.0
# 4                               []  ...                   6.0
#
#    lg_number_of_words  lg_number_of_complex_words  \
# 0                  37                           4
# 1                  21                           1
# 2                  13                           0
# 3                  20                           2
# 4                  42                           4
#
#    lg_percent_of_complex_words lg_number_of_sentences  \
# 0                    10.810811                      3
# 1                     4.761905                      1
# 2                     0.000000                      1
# 3                    10.000000                      1
# 4                     9.523810                      3
#
#   lg_average_sentence_length  lg_fog_index lg_pisarek_index  \
# 0                  14.000000      9.257658         8.200377
# 1                  22.000000     10.304762        10.766566
# 2                  17.000000      5.200000         6.500000
# 3                  20.000000     12.000000        11.180340
# 4                  17.666667      9.409524         8.466152
#
#    lg_contains_badword                                     purified_tweet
# 0                False  parę uchodźcy elektorat polskimi patriotami ra...
# 1                False  hello sory memory mediach wszędzie podają stud...
# 2                False  jadą islamscyuchodźcy ponoć kijowa panika prem...
# 3                False  polakom wpajane uchodźcy bliskiego wschodu ter...
# 4                False  póki uchodźcy uciekają wojną np masowymi morda...
#
# [5 rows x 36 columns]

# %%
from wordcloud import WordCloud
from PIL import Image

# %%
stringed_data = data['purified_tweet'].to_string()
wordcloud = WordCloud(width = 800, height = 400, random_state=1, background_color='white', colormap='winter', collocations=False).generate(stringed_data)
wordcloud.to_file("general_wordcloud.png")

# %%
# What are most popular hastags?

# %%
# What are most popular shared URLs?

# %%
# How many tweets that contain bad words?
