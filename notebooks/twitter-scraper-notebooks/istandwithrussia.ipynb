# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../../data/twitter-scraped-data/aantyukraine/processed.csv")

# %%
data.head()
# Out:
#                     id      conversation_id                 date  \
# 0  1498997605065314306  1498997605065314306  2022-03-02 13:24:13
# 1  1498931639505895425  1498931639505895425  2022-03-02 09:02:06
# 2  1498904031388782593  1498904031388782593  2022-03-02 07:12:24
# 3  1498997703245660164  1498997703245660164  2022-03-02 13:24:37
# 4  1498722094850392065  1497832945444585474  2022-03-01 19:09:26
#
#                                                tweet  \
# 0                             lawda #IStandWithPutin
# 1  USA Power 🥱  #Russians #RussiaUkraine #Russian...
# 2  Krwa li na bejjati fir se.. 🤣🤣 #IStandWithPuti...
# 3                           LAwda  #istandwithrussia
# 4  @HennyVotes @Gadhwara27 @Talkles53885697 Ukrai...
#
#                                             hashtags          user_id_str  \
# 0                                ['istandwithputin']  1009658561834565632
# 1  ['russians', 'russiaukraine', 'russianukrainia...  1349760852799483906
# 2            ['istandwithputin', 'ukrainerussiawar']  1235464610175528961
# 3                               ['istandwithrussia']  1009658561834565632
# 4                               ['istandwithrussia']  1493214294959431683
#
#           username            name  \
# 0     felixmakwana   Felix Makwana
# 1     TimesByTalha           Talha
# 2  RahulKu22017449           RãHuL
# 3     felixmakwana   Felix Makwana
# 4          loy0121  Fawad Loy 🇷🇺🇨🇳
#
#                                                 link urls  ...  \
# 0  https://twitter.com/felixmakwana/status/149899...   []  ...
# 1  https://twitter.com/TimesByTalha/status/149893...   []  ...
# 2  https://twitter.com/RahulKu22017449/status/149...   []  ...
# 3  https://twitter.com/felixmakwana/status/149899...   []  ...
# 4  https://twitter.com/loy0121/status/14987220948...   []  ...
#
#   lg_noun_to_verb_ratio  lg_number_of_words  lg_number_of_complex_words  \
# 0                  -1.0                   1                           0
# 1                  -1.0                   3                           0
# 2                  -1.0                   7                           0
# 3                  -1.0                   1                           0
# 4                  -1.0                   4                           0
#
#    lg_percent_of_complex_words lg_number_of_sentences  \
# 0                          0.0                      1
# 1                          0.0                      1
# 2                          0.0                      2
# 3                          0.0                      1
# 4                          0.0                      1
#
#   lg_average_sentence_length  lg_fog_index lg_pisarek_index  \
# 0                        1.0           0.4             0.50
# 1                        3.0           1.2             1.50
# 2                        4.5           1.4             1.75
# 3                        1.0           0.4             0.50
# 4                        5.0           1.6             2.00
#
#    lg_contains_badword                 purified_tweet
# 0                False                          lawda
# 1                False                      usa power
# 2                False         krwa li bejjati fir se
# 3                False                          lawda
# 4                False  ukrainian nazi terrorist army
#
# [5 rows x 36 columns]

# %%
from wordcloud import WordCloud
from PIL import Image

# %%
stringed_data = data['purified_tweet'].to_string()
wordcloud = WordCloud(width = 800, height = 400, random_state=1, background_color='white', colormap='winter', collocations=False).generate(stringed_data)
wordcloud.to_file("general_wordcloud.png")

# %%
# What are most popular hastags?

# %%
# What are most popular shared URLs?

# %%
# How many tweets that contain bad words?
