# %%
import pandas as pd
import numpy as np

import spacy
# load spacy model with binaries and configuration information
nlp = spacy.load("pl_core_news_lg")

import re
from unidecode import unidecode

# %%
fakenews_df = pd.read_csv("C:/Users/kubas/Desktop/narrator/database/fact-checks/fakenews.pl/2021-11-11.csv")
demagog_df = pd.read_csv("C:/Users/kubas/Desktop/narrator/database/fact-checks/demagog.org.pl/2021-11-12.csv")
fakehunter_df = pd.read_csv("C:/Users/kubas/Desktop/narrator/database/fact-checks/fakehunter.pap.pl/2021-11-12.csv")

# %%
def to_lowercase(text):
    return text.lower()

pl_stopwords = set(open("C:/Users/kubas/Desktop/narrator/database/ext/pl_stopwords.txt", encoding="utf-8", mode='r').read().split("\n"))
def remove_stopwords(text, stopwords = pl_stopwords):
    return ' '.join([word for word in text.split(" ") if word not in stopwords])
    
def remove_mentions(text):
    return re.sub(r'\B\@([\w\-]+)','', text)    

def remove_hashtags(text):
    return re.sub(r'\B\#([\w\-]+)','', text)    

def remove_urls(text):
    return re.sub(r'http\S+','', text)    

def remove_emojis(text):
    regrex_pattern = re.compile(pattern = "["
    u"\U0001F600-\U0001F64F"  # emoticons
    u"\U0001F300-\U0001F5FF"  # symbols & pictographs
    u"\U0001F680-\U0001F6FF"  # transport & map symbols
    u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                       "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'', text)

def remove_punctuation(text):
    return re.sub(r'[^\w\s]','', text)    

def remove_numbers(text):
    return re.sub(r' \d+','', text)    

def remove_n_lenght_words(text, n = 2):
    return ' '.join([word for word in text.split(" ") if len(word) > n])

def remove_duplicated_spaces(text):
    return " ".join(text.split())

def preprocess_text(text):
    text = to_lowercase(text)
    text = remove_mentions(text)
    text = remove_hashtags(text)
    text = remove_urls(text)
    text = remove_emojis(text)
    text = remove_punctuation(text)
    text = remove_numbers(text)
    text = remove_n_lenght_words(text)
    text = remove_duplicated_spaces(text)
    return text

def preprocess_new_text(text):
    return nlp(preprocess_text(text))

# %%
def process_fakenews_df(df):
    # Deletetes useless column
    df.drop('Unnamed: 0', 1, inplace = True)
    
    # Parse date
    months = {' stycznia ': '-1-', ' lutego ': '-2-', ' marca ': '-3-',' kwietnia ': '-4-',' maja ': '-5-',' czerwca ':'-6-',' lipca ':'-7-',' sierpnia ':'-8-',' września ':'-9-',' października ':'-10-',' listopada ':'-11-',' grudnia ':'-12-'}
    df['date'].replace(months, regex = True, inplace = True)    
    df['date'] = df['date'].str[10:]
    
    # Preprocessing text later used for spaCy
    #df['pr_title'] = df['title'].apply(lambda text: preprocess_text(text))
    
    # Applying spaCy Doc constructor
    # df['nlp_title'] = list(nlp.pipe(df['pr_title']))
    return df

def process_demagog_df(df):
    # Deletetes useless column
    df.drop('Unnamed: 0', 1, inplace = True)
    
    df['date'] = df['date'].str.replace('.','-',regex=True)
    df['date'] = df['date'].str[-10:]
    
    # Preprocessing text later used for spaCy
    # df['pr_title'] = df['title'].apply(lambda text: preprocess_text(text))
    
    # Applying spaCy Doc constructor
    # df['nlp_title'] = list(nlp.pipe(df['pr_title']))

    return df

def process_fakehunter_df(df):
    # Deletetes useless column
    df.drop('Unnamed: 0', 1, inplace = True)
    
    df['date'] = df['date'].str.replace('.','-',regex=True)
    df['date'] = df['date'].str[16:-6]
    
    # Preprocessing text later used for spaCy
    #df['pr_title'] = df['title'].apply(lambda text: preprocess_text(text))
    
    # Applying spaCy Doc constructor
    #df['nlp_title'] = list(nlp.pipe(df['pr_title']))
    return df

def top_n_sisters(n, text, df):
    text = preprocess_new_text(text)
    
    df['similarity_to_text'] = df['nlp_title'].apply(lambda new_text: new_text.similarity(text))
    return df.sort_values(by=['similarity_to_text'], ascending=False).head(n)

# %%
df = process_fakenews_df(fakenews_df)
df.to_csv("clean_fakenews.csv")

# %%
df = process_fakehunter_df(fakehunter_df)
df.to_csv("clean_fakehunter.csv")

# %%
df = process_demagog_df(demagog_df)
df.to_csv("clean_demagog.csv")

# %%
text = "Oszukali społeczeństwo tlenkiem grafenu, skutecznością amantadyny, a na końcu - lekiem dla koni (iwermektyna). W rzeczywistości najskuteczniejsze okazują się być: szczepienia ochronne, zasady san. - epid., tlen, przeciwciała monoklonalne, sterydy, niektóre leki p/wirusowe."
top_n_sisters(40, text, df)
# Out:
#                                                    url  \
# 375  https://fakenews.pl/zdrowie/wczesniaki-nie-dos...
# 369  https://fakenews.pl/zdrowie/nie-leki-na-raka-n...
# 275  https://fakenews.pl/zdrowie/szczepionki-nie-za...
# 304  https://fakenews.pl/zdrowie/prognozowane-powik...
# 243  https://fakenews.pl/zdrowie/wiekszosc-zmarlych...
# 301  https://fakenews.pl/zdrowie/ksiadz-z-gorzowa-s...
# 317  https://fakenews.pl/zdrowie/szczepionki-z-ludz...
# 277  https://fakenews.pl/zdrowie/nie-szczepienia-ni...
# 156  https://fakenews.pl/spoleczenstwo/nie-edukator...
# 264  https://fakenews.pl/zdrowie/nie-chip-ze-szczep...
# 244  https://fakenews.pl/zdrowie/nie-stawianie-bani...
# 303  https://fakenews.pl/zdrowie/szczepienie-na-cov...
# 183  https://fakenews.pl/spoleczenstwo/masowe-szcze...
# 254  https://fakenews.pl/zdrowie/przymusowe-szczepi...
# 280  https://fakenews.pl/zdrowie/nowe-badanie-ujawn...
# 12   https://fakenews.pl/polityka/pap-jest-porozumi...
# 293  https://fakenews.pl/zdrowie/rada-europy-szczep...
# 145  https://fakenews.pl/spoleczenstwo/narkotyki-ni...
# 256  https://fakenews.pl/zdrowie/szczepienia-przeci...
# 111  https://fakenews.pl/spoleczenstwo/nie-zdjecia-...
# 296  https://fakenews.pl/zdrowie/nie-najpiekniejsze...
# 223  https://fakenews.pl/technologia/nie-elektrowni...
# 276  https://fakenews.pl/zdrowie/nie-szczepionki-ni...
# 326  https://fakenews.pl/zdrowie/pis-wprowadzi-przy...
# 224  https://fakenews.pl/technologia/czy-dostawy-en...
# 350  https://fakenews.pl/zdrowie/nie-w-polsce-nie-o...
# 377  https://fakenews.pl/zdrowie/czy-truvada-lek-na...
# 281  https://fakenews.pl/zdrowie/czy-w-walbrzychu-s...
# 185  https://fakenews.pl/spoleczenstwo/nie-zdjecie-...
# 271  https://fakenews.pl/zdrowie/nie-linie-lotnicze...
# 248  https://fakenews.pl/zdrowie/prezydent-chorwacj...
# 5    https://fakenews.pl/polityka/maria-kurowska-pi...
# 375  (wcześniaki, nie, dostaną, leków, które, ratuj...            0.758218
# 369  (nie, leki, na, raka, nie, zostały, skreślone,...            0.754324
# 275  (szczepionki, nie, zapobiegają, transmisji, wi...            0.748967
# 304  (prognozowane, powikłania, poszczepienne, covi...            0.738897
# 243  (większość, zmarłych, powodu, covid19, to, oso...            0.738079
# 301  (ksiądz, gorzowa, szczepionki, na, covid19, wy...            0.724161
# 317        (szczepionki, ludzkich, płodów, sprawdzamy)            0.721983
# 277  (nie, szczepienia, nie, spowodowały, katastrof...            0.719534
# 156  (nie, edukatorzy, seksualni, nie, podają, dzie...            0.717714
# 264  (nie, chip, ze, szczepionki, na, covid19, nie,...            0.717670
# 244  (nie, stawianie, baniek, nie, usunie, organizm...            0.715434
# 303  (szczepienie, na, covid19, przez, bluzkę, nie,...            0.710427
# 183  (masowe, szczepienia, wsparcie, żywieniowe, pr...            0.706188
# 254  (przymusowe, szczepienia, dzieci, australii, f...            0.691329
# 280  (nowe, badanie, ujawnia, że, szczepionka, firm...            0.689205
# 12   (pap, jest, porozumienie, ws, zawieszenia, pat...            0.681846
# 293  (rada, europy, szczepienia, przeciw, covid19, ...            0.681732
# 145  (narkotyki, nie, będą, sprzedawane, między, ta...            0.680801
# 256  (szczepienia, przeciwko, covid19, to, eksperym...            0.678336
# 111  (nie, zdjęcia, madrytu, bukaresztu, nie, przed...            0.676249
# 296  (nie, najpiękniejsze, zdjęcie, roku, nie, prze...            0.675577
# 223  (nie, elektrownia, czarnobylska, nie, stanowi,...            0.674128
# 276      (nie, szczepionki, nie, przyciągają, magnesu)            0.673754
# 326  (pis, wprowadzi, przymusowe, szczepienia, na, ...            0.673176
# 224  (czy, dostawy, energii, oze, niemczech, został...            0.667963
# 350  (nie, polsce, nie, odbywa, się, dezynfekcja, p...            0.667105
# 377  (czy, truvada, lek, na, hiv, uszkadza, kości, ...            0.662726
# 281  (czy, wałbrzychu, szczepienia, na, covid19, są...            0.660569
# 185  (nie, zdjęcie, tonących, uchodźców, nie, jest,...            0.660318
# 271  (nie, linie, lotnicze, nie, zakażą, lotów, oso...            0.659913
# 248  (prezydent, chorwacji, wstrzymuje, szczepienia...            0.658716
# 5    (maria, kurowska, pis, stare, drzewa, nie, pro...            0.656789
# 287       (tak, maski, ffp2, chronią, przed, wirusami)            0.656432
# 370  (nie, chiny, nie, zamierzają, uśmiercić, pacje...            0.653842
# 128  (tak, sylwestrowy, zakaz, przemieszczania, się...            0.650644
# 294  (nie, ten, wykres, nie, przedstawia, ryzyka, z...            0.649463
# 222  (setki, wyrzuconych, elektryków, paryża, rozkł...            0.648240
# 265  (czy, portugalii, tylko, pacjentów, zmarło, po...            0.644894
# 135  (nie, transseksualny, człowiekjeleń, nie, zost...            0.644852
# 333  (limeng, yan, ujawnia, sztuczne, pochodzenie, ...            0.644814

# %%
preprocess_new_text(text)
# Out:
# oszukali społeczeństwo tlenkiem grafenu skutecznością amantadyny na końcu lekiem dla koni iwermektyna rzeczywistości najskuteczniejsze okazują się być szczepienia ochronne zasady san epid tlen przeciwciała monoklonalne sterydy niektóre leki pwirusowe
